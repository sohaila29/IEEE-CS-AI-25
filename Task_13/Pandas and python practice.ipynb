# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Question 1 :  Import CSV file (1 Mark)
#
#
# Write code to load the alumni csv dataset into a Pandas DataFrame called 'alumni'.

# %%
df = pd.read_csv('alumni.csv')

# %% [markdown]
# ### Question 2 :  Understand the data set (5 Marks)
#
# Use the following pandas commands to understand the data set: a) head, b) tail, c) dtypes, d) info, e) describe

# %%
df.head()
# Out:
#    Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0            2004    Male         Single      Standard Diploma       Yes
# 1            2005    Male        Married  College Prep Diploma        No
# 2            2006  Female         Single      Standard Diploma       Yes
# 3            2007    Male        Married      Standard Diploma        No
# 4            2006  Female       Divorced      Standard Diploma       Yes
#
#    Salary    Fee Savings ($)
# 0  125000  10869     $86,000
# 1  100000  10869    $116,000
# 2   70000  10869     $52,000
# 3  120000  10869     $76,000
# 4   95000  11948     $52,000

# %%
df.tail()
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 83            2007    Male         Single      Standard Diploma        No
# 84            2008       M         Single  College Prep Diploma       Yes
# 85            2009    Male        Married      Standard Diploma        No
# 86            2005  Female       Divorced      Standard Diploma       Yes
# 87            2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)
# 83   75000  12066     $16,000
# 84   65000  12066     $72,000
# 85   75000  12066     $46,000
# 86  100000  12067     $32,000
# 87   75000  12067     $67,000

# %%
df.dtypes
# Out:
# Year Graduated     int64
# Gender            object
# Marital Status    object
# Diploma Type      object
# Defaulted         object
# Salary             int64
# Fee                int64
# Savings ($)       object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year Graduated  88 non-null     int64
#  1   Gender          88 non-null     object
#  2   Marital Status  88 non-null     object
#  3   Diploma Type    88 non-null     object
#  4   Defaulted       88 non-null     object
#  5   Salary          88 non-null     int64
#  6   Fee             88 non-null     int64
#  7   Savings ($)     88 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 5.6+ KB

# %%
df.describe().round(2)
# Out:
#        Year Graduated     Salary       Fee
# count           88.00      88.00     88.00
# mean          2006.48   84090.91  11708.73
# std              1.56   21234.13   1110.65
# min           2004.00   35000.00  10869.00
# 25%           2005.00   75000.00  10968.00
# 50%           2006.50   75000.00  11696.00
# 75%           2008.00   90000.00  12058.25
# max           2009.00  160000.00  20960.00

# %%
df.shape
# Out:
# (88, 8)

# %% [markdown]
# ### Question 3 :  Working with the data set (4)
#
# a) get the median, b) mean and c) standard deviation for the 'Salary' column

# %%
df['Salary'].median()
# Out:
# 75000.0

# %%
df['Salary'].mean().round(2) # the same in df.describe
# Out:
# 84090.91

# %%
df['Salary'].std() # same in df.describe
# Out:
# 21234.128008173615

# %% [markdown]
# # Select row at index 3

# %%
df.loc[3]
df.iloc[3]
# Out:
# Year Graduated                2007
# Gender                        Male
# Marital Status             Married
# Diploma Type      Standard Diploma
# Defaulted                       No
# Salary                      120000
# Fee                          10869
# Savings ($)                $76,000
# Name: 3, dtype: object

# %% [markdown]
# # Select rows with over 70,000 on the salary

# %%
high_salary = (df['Salary'] > 70000)
df.loc[high_salary]
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male         Single      Standard Diploma       Yes
# 1             2005    Male        Married  College Prep Diploma        No
# 3             2007    Male        Married      Standard Diploma        No
# 4             2006  Female       Divorced      Standard Diploma       Yes
# 6             2006    Male       Divorced      Standard Diploma        No
# ..             ...     ...            ...                   ...       ...
# 81            2005  Female         Single      Standard Diploma       Yes
# 83            2007    Male         Single      Standard Diploma        No
# 85            2009    Male        Married      Standard Diploma        No
# 86            2005  Female       Divorced      Standard Diploma       Yes
# 87            2006    Male        Married      Standard Diploma       Yes
#
#     Salary    Fee Savings ($)
# 0   125000  10869     $86,000
# 1   100000  10869    $116,000
# 3   120000  10869     $76,000
# 4    95000  11948     $52,000
# 6   160000  11724    $120,000
# ..     ...    ...         ...
# 81   90000  12066     $16,000
# 83   75000  12066     $16,000
# 85   75000  12066     $46,000
# 86  100000  12067     $32,000
# 87   75000  12067     $67,000
#
# [68 rows x 8 columns]

# %% [markdown]
# # Update coulmn values in Marital Status to a charcheter crossponding it's value
# for example Single ->S ,Married->M and so on

# %%
df['Marital Status'].value_counts()
# Out:
# Marital Status
# Married     35
# Single      34
# Divorced    19
# Name: count, dtype: int64

# %%
dict = {
    'Single' : 'S',
    'Married' : 'M',
    'Divorced' : 'D'
}

# %%
df['Marital Status'] = df['Marital Status'].replace(dict)

# %%
df.head()
# Out:
#    Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0            2004    Male              S      Standard Diploma       Yes
# 1            2005    Male              M  College Prep Diploma        No
# 2            2006  Female              S      Standard Diploma       Yes
# 3            2007    Male              M      Standard Diploma        No
# 4            2006  Female              D      Standard Diploma       Yes
#
#    Salary    Fee Savings ($)
# 0  125000  10869     $86,000
# 1  100000  10869    $116,000
# 2   70000  10869     $52,000
# 3  120000  10869     $76,000
# 4   95000  11948     $52,000

# %% [markdown]
# # Drop the Fee coulmn

# %%
df = df.drop('Fee', axis=1)
#df.drop(columns = ['fee'], inplace = True)

# %%
df.shape
# Out:
# (88, 7)

# %% [markdown]
# # ADD a New row to the data set

# %%
df['Diploma Type'].value_counts()
# Out:
# Diploma Type
# Standard Diploma        65
# College Prep Diploma    23
# Name: count, dtype: int64

# %%
dict = {
    'Year Graduated': 2027,
    'Gender' : 'Female',
    'Marital Status' : 'S',
    'Diploma Type' : 'College Prep Diploma',
    'Defaulted' : 'Yes',
    'Salary' : 870000,
    'Savings ($)': '$570965'
}

# %%
df.append(dict , ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6864\767728869.py in ?()
# ----> 1 df.append(dict , ignore_index = True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df2 = pd.DataFrame([dict])
df2
# Out:
#    Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0            2027  Female              S  College Prep Diploma       Yes
#
#    Salary Savings ($)
# 0  870000     $570965

# %%
df = pd.concat([df, df2], ignore_index=True)
df.tail()
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 84            2008       M              S  College Prep Diploma       Yes
# 85            2009    Male              M      Standard Diploma        No
# 86            2005  Female              D      Standard Diploma       Yes
# 87            2006    Male              M      Standard Diploma       Yes
# 88            2027  Female              S  College Prep Diploma       Yes
#
#     Salary Savings ($)
# 84   65000     $72,000
# 85   75000     $46,000
# 86  100000     $32,000
# 87   75000     $67,000
# 88  870000     $570965

# %% [markdown]
# # Remove all rows where year geaduated is under 2006

# %%
filt = (df['Year Graduated'] < 2006)

# %%
df[filt]
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 0             2004    Male              S      Standard Diploma       Yes
# 1             2005    Male              M  College Prep Diploma        No
# 9             2005  Female              S      Standard Diploma       Yes
# 16            2004    Male              D      Standard Diploma       Yes
# 17            2005  Female              S      Standard Diploma       Yes
# 21            2004    Male              M      Standard Diploma       Yes
# 22            2005  Female              S      Standard Diploma       Yes
# 25            2004    Male              M      Standard Diploma       Yes
# 26            2005  Female              D  College Prep Diploma        No
# 29            2004    Male              S      Standard Diploma       Yes
# 30            2005    Male              S      Standard Diploma        No
# 39            2004  Female              M  College Prep Diploma       Yes
# 40            2005  Female              S      Standard Diploma       Yes
# 45            2005  Female              S  College Prep Diploma       Yes
# 49            2004  Female              M      Standard Diploma        No
# 50            2005    Male              D      Standard Diploma       Yes
# 51            2005  Female              M      Standard Diploma       Yes
# 56            2004    Male              S      Standard Diploma       Yes
# 57            2005    Male              M      Standard Diploma       Yes
# 60            2004    Male              D      Standard Diploma       Yes
# 61            2005  Female              M  College Prep Diploma        No
# 69            2004  Female              M      Standard Diploma       Yes
# 70            2005  Female              D      Standard Diploma        No
# 75            2004  Female              M      Standard Diploma       Yes
# 76            2005    Male              S      Standard Diploma        No
# 81            2005  Female              S      Standard Diploma       Yes
# 86            2005  Female              D      Standard Diploma       Yes
#
#     Salary Savings ($)
# 0   125000     $86,000
# 1   100000    $116,000
# 9    90000     $30,000
# 16   95000      $6,000
# 17   60000     $36,000
# 21   90000     $67,000
# 22   35000     $40,000
# 25   75000     $57,000
# 26   90000     $64,000
# 29  110000     $52,000
# 30   60000     $57,000
# 39   90000     $67,000
# 40   65000     $10,000
# 45   75000     $32,000
# 49  110000    $103,000
# 50   75000     $37,000
# 51   90000     $24,000
# 56  100000     $12,000
# 57   75000     $16,000
# 60   85000     $52,000
# 61   90000     $46,000
# 69   65000     $32,000
# 70   75000     $67,000
# 75   85000     $24,000
# 76   90000     $52,000
# 81   90000     $16,000
# 86  100000     $32,000

# %%
df.drop(index = df[filt].index)
# Out:
#     Year Graduated  Gender Marital Status          Diploma Type Defaulted  \
# 2             2006  Female              S      Standard Diploma       Yes
# 3             2007    Male              M      Standard Diploma        No
# 4             2006  Female              D      Standard Diploma       Yes
# 5             2007  Female              M  College Prep Diploma        No
# 6             2006    Male              D      Standard Diploma        No
# ..             ...     ...            ...                   ...       ...
# 83            2007    Male              S      Standard Diploma        No
# 84            2008       M              S  College Prep Diploma       Yes
# 85            2009    Male              M      Standard Diploma        No
# 87            2006    Male              M      Standard Diploma       Yes
# 88            2027  Female              S  College Prep Diploma       Yes
#
#     Salary Savings ($)
# 2    70000     $52,000
# 3   120000     $76,000
# 4    95000     $52,000
# 5    60000     $67,000
# 6   160000    $120,000
# ..     ...         ...
# 83   75000     $16,000
# 84   65000     $72,000
# 85   75000     $46,000
# 87   75000     $67,000
# 88  870000     $570965
#
# [62 rows x 7 columns]
